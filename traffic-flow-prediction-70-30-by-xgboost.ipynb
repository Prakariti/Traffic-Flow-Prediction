# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/traffic-prediction-dataset/Traffic.csv
# /kaggle/input/traffic-prediction-dataset/TrafficTwoMonth.csv

# %% [markdown]
# # 1| Import Libraries

# %%
# Basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# For model and metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score
from xgboost import XGBClassifier

# Warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2| Read Dataset

# %%
# Load the dataset
data = pd.read_csv('/kaggle/input/traffic-prediction-dataset/Traffic.csv')

# Display the first few rows
data.head()
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        31          0         4
# 1  12:15:00 AM    10         Tuesday        49          0         3
# 2  12:30:00 AM    10         Tuesday        46          0         3
# 3  12:45:00 AM    10         Tuesday        51          0         2
# 4   1:00:00 AM    10         Tuesday        57          6        15
#
#    TruckCount  Total Traffic Situation
# 0           4     39               low
# 1           3     55               low
# 2           6     55               low
# 3           5     58               low
# 4          16     94            normal

# %% [markdown]
# # 3| Data Preprocessing

# %%
# Check data types and head of the dataset
print(data.dtypes)
print(data.head())

# Identify categorical columns (usually object or string type)
categorical_cols = data.select_dtypes(include=['object']).columns.tolist()
print("Categorical Columns:", categorical_cols)

# Apply Label Encoding to all categorical columns
label_encoder = LabelEncoder()
for col in categorical_cols:
    data[col] = label_encoder.fit_transform(data[col])

# Separate features and target
X = data.drop('Traffic Situation', axis=1)
y = data['Traffic Situation']

# Standardize numeric features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Show shape of train and test sets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# Time                 object
# Date                  int64
# Day of the week      object
# CarCount              int64
# BikeCount             int64
# BusCount              int64
# TruckCount            int64
# Total                 int64
# Traffic Situation    object
# dtype: object
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        31          0         4
# 1  12:15:00 AM    10         Tuesday        49          0         3
# 2  12:30:00 AM    10         Tuesday        46          0         3
# 3  12:45:00 AM    10         Tuesday        51          0         2
# 4   1:00:00 AM    10         Tuesday        57          6        15
#
#    TruckCount  Total Traffic Situation
# 0           4     39               low
# 1           3     55               low
# 2           6     55               low
# 3           5     58               low
# 4          16     94            normal
# Categorical Columns: ['Time', 'Day of the week', 'Traffic Situation']
# X_train shape: (2083, 8)
# X_test shape: (893, 8)

# %% [markdown]
# # 4| Data Visualization

# %%
# Plot distribution of target variable
sns.countplot(x='Traffic Situation', data=data)
plt.title('Distribution of Traffic Situations')
plt.show()

# Correlation heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()

# %% [markdown]
# # 5| Train the model with XGBoost

# %%
# Initial Model (Basic)
xgb = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...)

# %% [markdown]
# # 6| Split the Data (70% Train, 30% Test)

# %%
from sklearn.model_selection import train_test_split

# Perform 70-30 train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.30, random_state=42, stratify=y)

# Display the shape of the splits
print("Training Set:")
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)

print("\nTesting Set:")
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# Training Set:
# X_train shape: (2083, 8)
# y_train shape: (2083,)
#
# Testing Set:
# X_test shape: (893, 8)
# y_test shape: (893,)

# %% [markdown]
# # 7| Train, Evaluate, and Visualize the Model

# %%
# ✅ Imports
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import matplotlib.pyplot as plt

# ✅ Build the model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='softmax'))   # Hidden Layer 1
model.add(Dense(32, activation='softmax'))                              # Hidden Layer 2
model.add(Dense(len(np.unique(y_train)), activation='softmax'))          # Output Layer

# ✅ Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# ✅ Train the model
history = model.fit(X_train, y_train,
                    epochs=100,
                    batch_size=16,
                    verbose=1,
                    validation_data=(X_test, y_test))

# ✅ Predict on test data
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# ✅ Evaluation Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')

# ✅ Print Results
print("\n📊 Model Evaluation (Batch Size = 16, Activation = softmax, Epochs = 100, Split = 70/30):")
print(f"✅ Accuracy : {accuracy:.4f}")
print(f"📌 Precision: {precision:.4f}")
print(f"📌 Recall   : {recall:.4f}")
print(f"🏅 F1 Score : {f1:.4f}")

# ✅ Visualization
plt.figure(figsize=(14, 5))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange')
plt.title('Model Accuracy Over Epochs (softmax, Batch Size 16)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', color='red')
plt.plot(history.history['val_loss'], label='Validation Loss', color='green')
plt.title('Model Loss Over Epochs (softmax, Batch Size 16)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# 2025-04-21 04:58:51.935264: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745211532.187881      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745211532.261333      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# I0000 00:00:1745211545.244420      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1745211545.245152      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745211548.194375     101 service.cc:148] XLA service 0x7c4eec006fb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745211548.195339     101 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1745211548.195370     101 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1745211548.402895     101 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 111/131 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5823 - loss: 1.3335
# I0000 00:00:1745211549.401224     101 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.5785 - loss: 1.3293 - val_accuracy: 0.5610 - val_loss: 1.2463
# Epoch 2/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5564 - loss: 1.2287 - val_accuracy: 0.5610 - val_loss: 1.1754
# Epoch 3/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5557 - loss: 1.1673 - val_accuracy: 0.5610 - val_loss: 1.1270
# Epoch 4/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5571 - loss: 1.1152 - val_accuracy: 0.5610 - val_loss: 1.0688
# Epoch 5/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5594 - loss: 1.0590 - val_accuracy: 0.5610 - val_loss: 0.9936
# Epoch 6/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5369 - loss: 1.0026 - val_accuracy: 0.7492 - val_loss: 0.9155
# Epoch 7/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7596 - loss: 0.9058 - val_accuracy: 0.7760 - val_loss: 0.8429
# Epoch 8/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7708 - loss: 0.8416 - val_accuracy: 0.7772 - val_loss: 0.7810
# Epoch 9/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7838 - loss: 0.7579 - val_accuracy: 0.7794 - val_loss: 0.7299
# Epoch 10/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7867 - loss: 0.7139 - val_accuracy: 0.7794 - val_loss: 0.6882
# Epoch 11/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7879 - loss: 0.6650 - val_accuracy: 0.7816 - val_loss: 0.6553
# Epoch 12/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7724 - loss: 0.6575 - val_accuracy: 0.7828 - val_loss: 0.6281
# Epoch 13/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7877 - loss: 0.6140 - val_accuracy: 0.7828 - val_loss: 0.6047
# Epoch 14/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7933 - loss: 0.5792 - val_accuracy: 0.7828 - val_loss: 0.5830
# Epoch 15/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7908 - loss: 0.5710 - val_accuracy: 0.8130 - val_loss: 0.5614
# Epoch 16/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8059 - loss: 0.5725 - val_accuracy: 0.8219 - val_loss: 0.5369
# Epoch 17/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8269 - loss: 0.5167 - val_accuracy: 0.8219 - val_loss: 0.5090
# Epoch 18/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8243 - loss: 0.4959 - val_accuracy: 0.8208 - val_loss: 0.4793
# Epoch 19/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8277 - loss: 0.4672 - val_accuracy: 0.8219 - val_loss: 0.4518
# Epoch 20/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8218 - loss: 0.4481 - val_accuracy: 0.8466 - val_loss: 0.4250
# Epoch 21/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8510 - loss: 0.4304 - val_accuracy: 0.8589 - val_loss: 0.4040
# Epoch 22/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8782 - loss: 0.3968 - val_accuracy: 0.8656 - val_loss: 0.3846
# Epoch 23/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8881 - loss: 0.3660 - val_accuracy: 0.8735 - val_loss: 0.3678
# Epoch 24/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9025 - loss: 0.3343 - val_accuracy: 0.8779 - val_loss: 0.3531
# Epoch 25/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9045 - loss: 0.3279 - val_accuracy: 0.8757 - val_loss: 0.3409
# Epoch 26/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9151 - loss: 0.3013 - val_accuracy: 0.8802 - val_loss: 0.3307
# Epoch 27/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9047 - loss: 0.3214 - val_accuracy: 0.8779 - val_loss: 0.3224
# Epoch 28/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9041 - loss: 0.3069 - val_accuracy: 0.8835 - val_loss: 0.3139
# Epoch 29/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9174 - loss: 0.2867 - val_accuracy: 0.8813 - val_loss: 0.3075
# Epoch 30/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9185 - loss: 0.2811 - val_accuracy: 0.8869 - val_loss: 0.3010
# Epoch 31/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9048 - loss: 0.2918 - val_accuracy: 0.8858 - val_loss: 0.2958
# Epoch 32/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9673 - loss: 0.1186 - val_accuracy: 0.9351 - val_loss: 0.1714
# Epoch 68/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9663 - loss: 0.1182 - val_accuracy: 0.9351 - val_loss: 0.1704
# Epoch 69/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9628 - loss: 0.1277 - val_accuracy: 0.9362 - val_loss: 0.1696
# Epoch 70/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9658 - loss: 0.1146 - val_accuracy: 0.9362 - val_loss: 0.1681
# Epoch 71/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9632 - loss: 0.1256 - val_accuracy: 0.9384 - val_loss: 0.1650
# Epoch 72/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9679 - loss: 0.1159 - val_accuracy: 0.9395 - val_loss: 0.1652
# Epoch 73/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9669 - loss: 0.1257 - val_accuracy: 0.9373 - val_loss: 0.1667
# Epoch 74/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9684 - loss: 0.1051 - val_accuracy: 0.9373 - val_loss: 0.1622
# Epoch 75/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9695 - loss: 0.1150 - val_accuracy: 0.9328 - val_loss: 0.1640
# Epoch 76/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9653 - loss: 0.1190 - val_accuracy: 0.9373 - val_loss: 0.1625
# Epoch 77/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9691 - loss: 0.1104 - val_accuracy: 0.9373 - val_loss: 0.1611
# Epoch 78/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9748 - loss: 0.0937 - val_accuracy: 0.9373 - val_loss: 0.1605
# Epoch 79/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9616 - loss: 0.1199 - val_accuracy: 0.9395 - val_loss: 0.1602
# Epoch 80/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9671 - loss: 0.1161 - val_accuracy: 0.9384 - val_loss: 0.1594
# Epoch 81/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9641 - loss: 0.1173 - val_accuracy: 0.9373 - val_loss: 0.1586
# Epoch 82/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9723 - loss: 0.0911 - val_accuracy: 0.9373 - val_loss: 0.1569
# Epoch 83/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9671 - loss: 0.1086 - val_accuracy: 0.9373 - val_loss: 0.1592
# Epoch 84/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9639 - loss: 0.1049 - val_accuracy: 0.9418 - val_loss: 0.1552
# Epoch 85/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9656 - loss: 0.1057 - val_accuracy: 0.9384 - val_loss: 0.1555
# Epoch 86/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9688 - loss: 0.1159 - val_accuracy: 0.9418 - val_loss: 0.1550
# Epoch 87/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9736 - loss: 0.0896 - val_accuracy: 0.9406 - val_loss: 0.1537
# Epoch 88/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9692 - loss: 0.1079 - val_accuracy: 0.9429 - val_loss: 0.1522
# Epoch 89/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9704 - loss: 0.0999 - val_accuracy: 0.9395 - val_loss: 0.1512
# Epoch 90/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9687 - loss: 0.1121 - val_accuracy: 0.9429 - val_loss: 0.1508
# Epoch 91/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9700 - loss: 0.0967 - val_accuracy: 0.9418 - val_loss: 0.1498
# Epoch 92/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9737 - loss: 0.0942 - val_accuracy: 0.9418 - val_loss: 0.1514
# Epoch 93/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9727 - loss: 0.1025 - val_accuracy: 0.9406 - val_loss: 0.1507
# Epoch 94/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9727 - loss: 0.0948 - val_accuracy: 0.9440 - val_loss: 0.1473
# Epoch 95/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9715 - loss: 0.1111 - val_accuracy: 0.9418 - val_loss: 0.1519
# Epoch 96/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9696 - loss: 0.1062 - val_accuracy: 0.9451 - val_loss: 0.1469
# Epoch 97/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9755 - loss: 0.0831 - val_accuracy: 0.9451 - val_loss: 0.1480
# Epoch 98/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9707 - loss: 0.0939 - val_accuracy: 0.9451 - val_loss: 0.1456
# Epoch 99/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9764 - loss: 0.0812 - val_accuracy: 0.9451 - val_loss: 0.1458
# Epoch 100/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9776 - loss: 0.0858 - val_accuracy: 0.9440 - val_loss: 0.1453
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
#
# 📊 Model Evaluation (Batch Size = 16, Activation = softmax, Epochs = 100, Split = 70/30):
# ✅ Accuracy : 0.9440
# 📌 Precision: 0.9288
# 📌 Recall   : 0.9111
# 🏅 F1 Score : 0.9190
